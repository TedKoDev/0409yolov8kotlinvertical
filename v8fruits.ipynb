# %% [markdown]
# <a href="https://colab.research.google.com/github/TedKoDev/0409yolov8kotlinvertical/blob/master/v8fruits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O Fruits_Data.zip https://public.roboflow.com/ds/zNgrbAvkrk?key=rsFdroJIR0
# Out:
# --2023-04-13 01:43:04--  https://public.roboflow.com/ds/zNgrbAvkrk?key=rsFdroJIR0
# Resolving public.roboflow.com (public.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to public.roboflow.com (public.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/5w20VzQObTXjJhTjq6kad9ubrm33/otiGOu7bL0WwwkUaV3og/1/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230413%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230413T014304Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
import zipfile
with zipfile.ZipFile ('/content/Fruits_Data.zip') as target_file :
      target_file.extractall('/content/Fruits_Data/')

# %%
# !pip install PyYAML
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yaml 

data = {'train' : '/content/Fruits_Data/train/images',
        'val' : '/content/Fruits_Data/valid/images',
        'test' : '/content/Fruits_Data/test/images',
       'names' : ['Apple', 'Apricot', 'Avocado', 'Banana', 'Beetroot', 'Blueberry', 'Cactus', 'Cantaloupe', 'Carambula', 'Cauliflower', 'Cherry', 'Chestnut', 'Clementine', 'Cocos', 'Dates', 'Eggplant', 'Ginger', 'Granadilla', 'Grape', 'Grapefruit', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mangostan', 'Maracuja', 'Melon', 'Mulberry', 'Nectarine', 'Nut', 'Onion', 'Orange', 'Papaya', 'Passion', 'Peach', 'Pear', 'Pepino', 'Pepper', 'Physalis', 'Pineapple', 'Pitahaya', 'Plum', 'Pomegranate', 'Pomelo', 'Potato', 'Quince', 'Rambutan', 'Raspberry', 'Redcurrant', 'Salak', 'Strawberry', 'Tamarillo', 'Tangelo', 'Tomato', 'Walnut'],
        'nc' : 63}

with open ('/content/Fruits_Data/Fruits_Data.yaml','w') as f: 
  yaml.dump(data, f)

with open ('/content/Fruits_Data/Fruits_Data.yaml','r') as f: 
  aquarium_yaml = yaml.safe_load(f)
  display(aquarium_yaml)
# Out:
# {'names': ['Apple',
#   'Apricot',
#   'Avocado',
#   'Banana',
#   'Beetroot',
#   'Blueberry',
#   'Cactus',
#   'Cantaloupe',
#   'Carambula',
#   'Cauliflower',
#   'Cherry',
#   'Chestnut',
#   'Clementine',
#   'Cocos',
#   'Dates',
#   'Eggplant',
#   'Ginger',
#   'Granadilla',
#   'Grape',
#   'Grapefruit',
#   'Guava',
#   'Hazelnut',
#   'Huckleberry',
#   'Kaki',
#   'Kiwi',
#   'Kohlrabi',
#   'Kumquats',
#   'Lemon',
#   'Limes',
#   'Lychee',
#   'Mandarine',
#   'Mango',
#   'Mangostan',
#   'Maracuja',
#   'Melon',
#   'Mulberry',
#   'Nectarine',
#   'Nut',
#   'Onion',
#   'Orange',
#   'Papaya',
#   'Passion',
#   'Peach',
#   'Pear',
#   'Pepino',
#   'Pepper',
#   'Physalis',
#   'Pineapple',
#   'Pitahaya',
#   'Plum',
#   'Pomegranate',
#   'Pomelo',
#   'Potato',
#   'Quince',
#   'Rambutan',
#   'Raspberry',
#   'Redcurrant',
#   'Salak',
#   'Strawberry',
#   'Tamarillo',
#   'Tangelo',
#   'Tomato',
#   'Walnut'],
#  'nc': 63,
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.6/509.6 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 24.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.75 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO ('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 64.8MB/s]

# %%
print (type(model.names),len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data='/content/Fruits_Data/Fruits_Data.yaml', epochs = 50 , patience=30, batch=32, imgsz = 640)
# Out:
# Ultralytics YOLOv8.0.75 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('/content/runs/detect/train/weights/best.pt')  # load a custom trained

# Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.75 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3017933 parameters, 0 gradients, 8.2 GFLOPs
#
# PyTorch: starting from /content/runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 67, 8400) (6.0 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 69.8 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ONNX: export success ✅ 10.1s, saved as /content/runs/detect/train/weights/best.onnx (11.7 MB)
#
# Export complete (11.7s)
# Results saved to /content/runs/detect/train/weights
# ...
